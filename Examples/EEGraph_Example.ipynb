# %% [markdown]
# <table><tr><td>Run the latest release of this notebook:</td><td><a href="https://colab.research.google.com/github/ufvceiec/EEGRAPH/blob/develop-refactor/Examples/EEGraph_Example.ipynb" alt="Open In Colab" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg"/></a></td></tr></table>

# %% [markdown]
# #Example Usage of EEGraph
#
# > This example explains how to use EEGraph library.

# %%
# install EEGraph if running on Google Colab
# %pip install EEGRAPH
# Out:
# Collecting EEGRAPH
#   Using cached EEGRAPH-0.1.17-py3-none-any.whl.metadata (6.6 kB)
# Collecting numpy==1.21.1 (from EEGRAPH)
#   Using cached numpy-1.21.1.zip (10.3 MB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ERROR: Exception:
# Traceback (most recent call last):
#   File "c:\Users\david\AppData\Local\Programs\Python\Python313\Lib\site-packages\pip\_internal\cli\base_command.py", line 106, in _run_wrapper
#     status = _inner_run()
#   File "c:\Users\david\AppData\Local\Programs\Python\Python313\Lib\site-packages\pip\_internal\cli\base_command.py", line 97, in _inner_run
#     return self.run(options, args)
#            ~~~~~~~~^^^^^^^^^^^^^^^
#   File "c:\Users\david\AppData\Local\Programs\Python\Python313\Lib\site-packages\pip\_internal\cli\req_command.py", line 67, in wrapper
#     return func(self, options, args)
#   File "c:\Users\david\AppData\Local\Programs\Python\Python313\Lib\site-packages\pip\_internal\commands\install.py", line 386, in run
#     requirement_set = resolver.resolve(
#         reqs, check_supported_wheels=not options.target_dir
#     )
#   File "c:\Users\david\AppData\Local\Programs\Python\Python313\Lib\site-packages\pip\_internal\resolution\resolvelib\resolver.py", line 95, in resolve
#     result = self._result = resolver.resolve(
#                             ~~~~~~~~~~~~~~~~^
#         collected.requirements, max_rounds=limit_how_complex_resolution_can_be
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "c:\Users\david\AppData\Local\Programs\Python\Python313\Lib\site-packages\pip\_vendor\resolvelib\resolvers.py", line 546, in resolve
#     state = resolution.resolve(requirements, max_rounds=max_rounds)
#   File "c:\Users\david\AppData\Local\Programs\Python\Python313\Lib\site-packages\pip\_vendor\resolvelib\resolvers.py", line 427, in resolve
#     failure_causes = self._attempt_to_pin_criterion(name)
#   File "c:\Users\david\AppData\Local\Programs\Python\Python313\Lib\site-packages\pip\_vendor\resolvelib\resolvers.py", line 239, in _attempt_to_pin_criterion
#     criteria = self._get_updated_criteria(candidate)
#   File "c:\Users\david\AppData\Local\Programs\Python\Python313\Lib\site-packages\pip\_vendor\resolvelib\resolvers.py", line 230, in _get_updated_criteria
#     self._add_to_criteria(criteria, requirement, parent=candidate)
#     ~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\david\AppData\Local\Programs\Python\Python313\Lib\site-packages\pip\_vendor\resolvelib\resolvers.py", line 173, in _add_to_criteria
#     if not criterion.candidates:
#            ^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\david\AppData\Local\Programs\Python\Python313\Lib\site-packages\pip\_vendor\resolvelib\structs.py", line 156, in __bool__
#     return bool(self._sequence)
#   File "c:\Users\david\AppData\Local\Programs\Python\Python313\Lib\site-packages\pip\_internal\resolution\resolvelib\found_candidates.py", line 174, in __bool__
#     return any(self)
#   File "c:\Users\david\AppData\Local\Programs\Python\Python313\Lib\site-packages\pip\_internal\resolution\resolvelib\found_candidates.py", line 162, in <genexpr>
#     return (c for c in iterator if id(c) not in self._incompatible_ids)
#                        ^^^^^^^^
#   File "c:\Users\david\AppData\Local\Programs\Python\Python313\Lib\site-packages\pip\_internal\resolution\resolvelib\found_candidates.py", line 53, in _iter_built
#     candidate = func()
#   File "c:\Users\david\AppData\Local\Programs\Python\Python313\Lib\site-packages\pip\_internal\resolution\resolvelib\factory.py", line 187, in _make_candidate_from_link
#     base: Optional[BaseCandidate] = self._make_base_candidate_from_link(
#                                     ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^
#         link, template, name, version
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "c:\Users\david\AppData\Local\Programs\Python\Python313\Lib\site-packages\pip\_internal\resolution\resolvelib\factory.py", line 233, in _make_base_candidate_from_link
#     self._link_candidate_cache[link] = LinkCandidate(
#                                        ~~~~~~~~~~~~~^
#         link,
#         ^^^^^
#     ...<3 lines>...
#         version=version,
#         ^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "c:\Users\david\AppData\Local\Programs\Python\Python313\Lib\site-packages\pip\_internal\resolution\resolvelib\candidates.py", line 304, in __init__
#     super().__init__(
#     ~~~~~~~~~~~~~~~~^
#         link=link,
#         ^^^^^^^^^^
#     ...<4 lines>...
#         version=version,
#         ^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "c:\Users\david\AppData\Local\Programs\Python\Python313\Lib\site-packages\pip\_internal\resolution\resolvelib\candidates.py", line 159, in __init__
#     self.dist = self._prepare()
#                 ~~~~~~~~~~~~~^^
#   File "c:\Users\david\AppData\Local\Programs\Python\Python313\Lib\site-packages\pip\_internal\resolution\resolvelib\candidates.py", line 236, in _prepare
#     dist = self._prepare_distribution()
#   File "c:\Users\david\AppData\Local\Programs\Python\Python313\Lib\site-packages\pip\_internal\resolution\resolvelib\candidates.py", line 315, in _prepare_distribution
#     return preparer.prepare_linked_requirement(self._ireq, parallel_builds=True)
#            ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\david\AppData\Local\Programs\Python\Python313\Lib\site-packages\pip\_internal\operations\prepare.py", line 527, in prepare_linked_requirement
#     return self._prepare_linked_requirement(req, parallel_builds)
#            ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\david\AppData\Local\Programs\Python\Python313\Lib\site-packages\pip\_internal\operations\prepare.py", line 642, in _prepare_linked_requirement
#     dist = _get_prepared_distribution(
#         req,
#     ...<3 lines>...
#         self.check_build_deps,
#     )
#   File "c:\Users\david\AppData\Local\Programs\Python\Python313\Lib\site-packages\pip\_internal\operations\prepare.py", line 72, in _get_prepared_distribution
#     abstract_dist.prepare_distribution_metadata(
#     ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^
#         finder, build_isolation, check_build_deps
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "c:\Users\david\AppData\Local\Programs\Python\Python313\Lib\site-packages\pip\_internal\distributions\sdist.py", line 56, in prepare_distribution_metadata
#     self._install_build_reqs(finder)
#     ~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^
#   File "c:\Users\david\AppData\Local\Programs\Python\Python313\Lib\site-packages\pip\_internal\distributions\sdist.py", line 126, in _install_build_reqs
#     build_reqs = self._get_build_requires_wheel()
#   File "c:\Users\david\AppData\Local\Programs\Python\Python313\Lib\site-packages\pip\_internal\distributions\sdist.py", line 103, in _get_build_requires_wheel
#     return backend.get_requires_for_build_wheel()
#            ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^^
#   File "c:\Users\david\AppData\Local\Programs\Python\Python313\Lib\site-packages\pip\_internal\utils\misc.py", line 702, in get_requires_for_build_wheel
#     return super().get_requires_for_build_wheel(config_settings=cs)
#            ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\david\AppData\Local\Programs\Python\Python313\Lib\site-packages\pip\_vendor\pyproject_hooks\_impl.py", line 196, in get_requires_for_build_wheel
#     return self._call_hook(
#            ~~~~~~~~~~~~~~~^
#         "get_requires_for_build_wheel", {"config_settings": config_settings}
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "c:\Users\david\AppData\Local\Programs\Python\Python313\Lib\site-packages\pip\_vendor\pyproject_hooks\_impl.py", line 402, in _call_hook
#     raise BackendUnavailable(
#     ...<4 lines>...
#     )
# pip._vendor.pyproject_hooks._impl.BackendUnavailable: Cannot import 'setuptools.build_meta'

# %%
# import the libary
# %pip install ../requirements.txt
import eegraph
# Out:
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: C:\Users\david\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip
# ERROR: Invalid requirement: '../requirements.txt': Expected package name at the start of dependency specifier
#     ../requirements.txt
#     ^
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Load Data into EEGraph
#
# To start, we load the data. We are using an EEG file in .gdf extension. Supported EEG file formats can be found in the [loading documentation](https://github.com/ufvceiec/EEGRAPH/wiki/Load-data-from-EEG).
# Three parameters can be specified:
# * **Path**: The path to the EEG file.
# * **Exclude**: Channels to be excluded from EEG data.
# * **Electrode_montage_path**: The path to an electrode montage set.

# %%
G = eegraph.Graph()
G.load_data(path = "control.edf")
# Out:
# Extracting EDF parameters from c:\Users\david\OneDrive\Escritorio\5 UFV\TFG\EEGRAPH\Examples\control.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
#
# EEG Information.
# Number of Channels: 63
# Sample rate: 500.0 Hz.
# Duration: 1467.998 seconds.
# Channel Names: ['Fp1', 'Fz', 'F3', 'F7', 'FT9', 'FC5', 'FC1', 'C3', 'T7', 'TP9', 'CP5', 'CP1', 'P3', 'P7', 'O1', 'Oz', 'O2', 'P4', 'P8', 'TP10', 'CP6', 'CP2', 'Cz', 'C4', 'T8', 'FT10', 'FC6', 'FC2', 'F4', 'F8', 'Fp2', 'AF7', 'AF3', 'AFz', 'F1', 'F5', 'FT7', 'FC3', 'C1', 'C5', 'TP7', 'CP3', 'P1', 'P5', 'PO7', 'PO3', 'POz', 'PO4', 'PO8', 'P6', 'P2', 'CPz', 'CP4', 'TP8', 'C6', 'C2', 'FC4', 'FT8', 'F6', 'AF8', 'AF4', 'F2', 'FCz']

# %% [markdown]
# ## Modelate Data
#
# The method Modelate will generate [NetworkX](https://networkx.org/documentation/stable/) graphs from the EEG file. All information can be found in [Modelate documentation](https://github.com/ufvceiec/EEGRAPH/wiki/Modelate-Data).
# * **Window size**: Desired window size, it will determine the amount of graphs generated.
# * **Connectivity**: Connectivity measure to compute. One of the listed in modelate documentation.
# * **Bands**: It is only required if connectivity measure needs it. `e.g. ['delta','theta','alpha','beta','gamma']`.
# * **Threshold**: User specific threshold. Default values can be found in [documentation](https://github.com/ufvceiec/EEGRAPH/wiki/Modelate-Data).

# %% [markdown]
# ### Without Frequency bands

# %% [markdown]
# In this first example we are using a window size of `2 seconds`, and connectivity measure `pearson_correlation`.

# %%
window = 2
connectivity_measure = 'pearson_correlation'

graphs, connectivity_matrix = G.modelate(window_size = window, connectivity = connectivity_measure)
# Out:
# Model Data.
# Pearson_correlation_Estimator()
# Intervals:  [(0, 1000.0), (1000.0, 2000.0), (2000.0, 3000.0), (3000.0, 4000.0), (4000.0, 5000.0), (5000.0, 6000.0), (6000.0, 7000.0), (7000.0, 8000.0), (8000.0, 9000.0), (9000.0, 10000.0), (10000.0, 11000.0), (11000.0, 12000.0), (12000.0, 13000.0), (13000.0, 14000.0), (14000.0, 15000.0), (15000.0, 16000.0), (16000.0, 17000.0), (17000.0, 18000.0), (18000.0, 19000.0), (19000.0, 20000.0), (20000.0, 21000.0), (21000.0, 22000.0), (22000.0, 23000.0), (23000.0, 24000.0), (24000.0, 25000.0), (25000.0, 26000.0), (26000.0, 27000.0), (27000.0, 28000.0), (28000.0, 29000.0), (29000.0, 30000.0), (30000.0, 31000.0), (31000.0, 32000.0), (32000.0, 33000.0), (33000.0, 34000.0), (34000.0, 35000.0), (35000.0, 36000.0), (36000.0, 37000.0), (37000.0, 38000.0), (38000.0, 39000.0), (39000.0, 40000.0), (40000.0, 41000.0), (41000.0, 42000.0), (42000.0, 43000.0), (43000.0, 44000.0), (44000.0, 45000.0), (45000.0, 46000.0), (46000.0, 47000.0), (47000.0, 48000.0), (48000.0, 49000.0), (49000.0, 50000.0), (50000.0, 51000.0), (51000.0, 52000.0), (52000.0, 53000.0), (53000.0, 54000.0), (54000.0, 55000.0), (55000.0, 56000.0), (56000.0, 57000.0), (57000.0, 58000.0), (58000.0, 59000.0), (59000.0, 60000.0), (60000.0, 61000.0), (61000.0, 62000.0), (62000.0, 63000.0), (63000.0, 64000.0), (64000.0, 65000.0), (65000.0, 66000.0), (66000.0, 67000.0), (67000.0, 68000.0), (68000.0, 69000.0), (69000.0, 70000.0), (70000.0, 71000.0), (71000.0, 72000.0), (72000.0, 73000.0), (73000.0, 74000.0), (74000.0, 75000.0), (75000.0, 76000.0), (76000.0, 77000.0), (77000.0, 78000.0), (78000.0, 79000.0), (79000.0, 80000.0), (80000.0, 81000.0), (81000.0, 82000.0), (82000.0, 83000.0), (83000.0, 84000.0), (84000.0, 85000.0), (85000.0, 86000.0), (86000.0, 87000.0), (87000.0, 88000.0), (88000.0, 89000.0), (89000.0, 90000.0), (90000.0, 91000.0), (91000.0, 92000.0), (92000.0, 93000.0), (93000.0, 94000.0), (94000.0, 95000.0), (95000.0, 96000.0), (96000.0, 97000.0), (97000.0, 98000.0), (98000.0, 99000.0), (99000.0, 100000.0), (100000.0, 101000.0), (101000.0, 102000.0), (102000.0, 103000.0), (103000.0, 104000.0), (104000.0, 105000.0), (105000.0, 106000.0), (106000.0, 107000.0), (107000.0, 108000.0), (108000.0, 109000.0), (109000.0, 110000.0), (110000.0, 111000.0), (111000.0, 112000.0), (112000.0, 113000.0), (113000.0, 114000.0), (114000.0, 115000.0), (115000.0, 116000.0), (116000.0, 117000.0), (117000.0, 118000.0), (118000.0, 119000.0), (119000.0, 120000.0), (120000.0, 121000.0), (121000.0, 122000.0), (122000.0, 123000.0), (123000.0, 124000.0), (124000.0, 125000.0), (125000.0, 126000.0), (126000.0, 127000.0), (127000.0, 128000.0), (128000.0, 129000.0), (129000.0, 130000.0), (130000.0, 131000.0), (131000.0, 132000.0), (132000.0, 133000.0), (133000.0, 134000.0), (134000.0, 135000.0), (135000.0, 136000.0), (136000.0, 137000.0), (137000.0, 138000.0), (138000.0, 139000.0), (139000.0, 140000.0), (140000.0, 141000.0), (141000.0, 142000.0), (142000.0, 143000.0), (143000.0, 144000.0), (144000.0, 145000.0), (145000.0, 146000.0), (146000.0, 147000.0), (147000.0, 148000.0), (148000.0, 149000.0), (149000.0, 150000.0), (150000.0, 151000.0), (151000.0, 152000.0), (152000.0, 153000.0), (153000.0, 154000.0), (154000.0, 155000.0), (155000.0, 156000.0), (156000.0, 157000.0), (157000.0, 158000.0), (158000.0, 159000.0), (159000.0, 160000.0), (160000.0, 161000.0), (161000.0, 162000.0), (162000.0, 163000.0), (163000.0, 164000.0), (164000.0, 165000.0), (165000.0, 166000.0), (166000.0, 167000.0), (167000.0, 168000.0), (168000.0, 169000.0), (169000.0, 170000.0), (170000.0, 171000.0), (171000.0, 172000.0), (172000.0, 173000.0), (173000.0, 174000.0), (174000.0, 175000.0), (175000.0, 176000.0), (176000.0, 177000.0), (177000.0, 178000.0), (178000.0, 179000.0), (179000.0, 180000.0), (180000.0, 181000.0), (181000.0, 182000.0), (182000.0, 183000.0), (183000.0, 184000.0), (184000.0, 185000.0), (185000.0, 186000.0), (186000.0, 187000.0), (187000.0, 188000.0), (188000.0, 189000.0), (189000.0, 190000.0), (190000.0, 191000.0), (191000. ...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 4
#       1 window = 2
#       2 connectivity_measure = 'pearson_correlation'
# ----> 4 graphs, connectivity_matrix = G.modelate(window_size = window, connectivity = connectivity_measure)
#
# File ~\OneDrive\Escritorio\5 UFV\TFG\EEGRAPH\eegraph\graph.py:108, in Graph.modelate(self, window_size, connectivity, bands, threshold, **kwargs)
#     105     print(search(connectivity_measures, connectivity))
#     107     model_data = ModelData(self.data, self.ch_names, eval(search(connectivity_measures, connectivity)))
# --> 108     connectivity_matrix, G = model_data.connectivity_workflow(bands, window_size, threshold)
#     110     return connectivity_matrix, G
#     112 # fMRI (nuevo comportamiento añadido)
#
# File ~\OneDrive\Escritorio\5 UFV\TFG\EEGRAPH\eegraph\modelateData.py:20, in ModelData.connectivity_workflow(self, bands, window_size, threshold)
#      17 if(threshold) is not None:
#      18     self.threshold = threshold
# ---> 20 self.connectivity_matrix = self._strategy.calculate_connectivity_workflow(self, bands, window_size)
#      21 print('\nThreshold:', self.threshold)
#      23 out = self._strategy.make_graph_workflow(self)
#
# File ~\OneDrive\Escritorio\5 UFV\TFG\EEGRAPH\eegraph\strategy.py:26, in Connectivity_No_Bands.calculate_connectivity_workflow(self, data, bands, window_size)
#      24 dont_need_bands(bands)
#      25 data_intervals, steps, self.flag = calculate_time_intervals(data.raw_data, data.sample_rate, data.sample_duration, window_size, data.sample_length)
# ---> 26 self.connectivity_matrix = calculate_connectivity(data_intervals, steps, data.num_channels, data.sample_rate, self)
#      28 return self.connectivity_matrix
#
# File ~\OneDrive\Escritorio\5 UFV\TFG\EEGRAPH\eegraph\tools.py:375, in calculate_connectivity(data_intervals, steps, channels, sample_rate, connectivity)
#     373     for x,i in enumerate(range(start, stop)):
#     374         for y,j in enumerate(range(start, stop)):
# --> 375             matrix[k][x,y] = connectivity.calculate_conn(data_intervals, i, j, sample_rate, channels)
#     377 if (connectivity.flag):
#     378     aux = np.zeros(shape=(intervals-1, channels, channels))
#
# File ~\OneDrive\Escritorio\5 UFV\TFG\EEGRAPH\eegraph\strategy.py:136, in Pearson_correlation_Estimator.calculate_conn(self, data_intervals, i, j, sample_rate, channels)
#     135 def calculate_conn(self, data_intervals, i, j, sample_rate, channels):
# --> 136     r, p_value = (stats.pearsonr(data_intervals[i],data_intervals[j]))
#     138     return r
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\_stats_py.py:4762, in pearsonr(x, y, alternative, method, axis)
#    4760 with np.errstate(invalid='ignore', divide='ignore'):
#    4761     normxm = xmax * xp_vector_norm(xm/xmax, axis=axis, keepdims=True)
# -> 4762     normym = ymax * xp_vector_norm(ym/ymax, axis=axis, keepdims=True)
#    4764 nconst_x = xp.any(normxm < threshold*xp.abs(xmean), axis=axis)
#    4765 nconst_y = xp.any(normym < threshold*xp.abs(ymean), axis=axis)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\_lib\_array_api.py:482, in xp_vector_norm(x, axis, keepdims, ord, xp)
#     479         return xp.sum(xp.conj(x) * x, axis=axis, keepdims=keepdims)**0.5
#     480 else:
#     481     # to maintain backwards compatibility
# --> 482     return np.linalg.norm(x, ord=ord, axis=axis, keepdims=keepdims)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\linalg\_linalg.py:2829, in norm(x, ord, axis, keepdims)
#    2826 elif ord is None or ord == 2:
#    2827     # special case for speedup
#    2828     s = (x.conj() * x).real
# -> 2829     return sqrt(add.reduce(s, axis=axis, keepdims=keepdims))
#    2830 # None of the str-type keywords for ord ('fro', 'nuc')
#    2831 # are valid for vectors
#    2832 elif isinstance(ord, str):
#
# KeyboardInterrupt:

# %% [markdown]
# Since the EEG file is 32 seconds long, it will generate 16 graphs with the specificied window size of 2 seconds. The two outputs are a list of NetworkX graphs and the corresponding adjacency matrix for the generated graphs.

# %% [markdown]
# ### With Frequency bands

# %% [markdown]
# In this first example we are using a window size of `4 seconds`, connectivity measure `squared_coherence`, frequency bands `['delta','theta','alpha','beta','gamma']`, and a specific threshold of `0.75`.

# %%
window = 4
connectivity_measure = 'squared_coherence'
freq_bands = ['delta','theta','alpha','beta','gamma']
threshold = 0.75

graphs, connectivity_matrix = G.modelate(window_size = window, connectivity = connectivity_measure, bands = freq_bands, threshold=threshold)

# %% [markdown]
# With this configuration of window size and frequency bands we generate 80 graphs.

# %% [markdown]
# ## Visualize  Graph

# %% [markdown]
# With this method we can visualize specific graphs. We need to specify the graph we want to visualize, and the name for the output html generated file.

# %%
name = 'graph_1'
G.visualize(graphs[10], name)

# %% [markdown]
# The graph plot can be visualized opening the html file that the 'visualized' method generates in the user's current folder.
